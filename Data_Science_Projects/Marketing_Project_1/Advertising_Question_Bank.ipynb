# %% [markdown]
# # 📘 Data Science Project Question Bank — Advertising Campaign Analysis

# %% [markdown]
# ## 🟢 Easy Level Questions

# %% [markdown]
# ### A. Customer Segmentation & Behavior (Very High Impact)

# %% [markdown]
# - 1. What is the average income of customers?
# - 2. Which year has the highest number of customer births?
# - 3. What is the average number of kids per customer?
# - 4. What is the distribution of customer marital status?
# - 5. What is the average spending on wines?
# - 6. Which product category has the highest average spending?
# - 7. How many customers accepted the marketing campaign Response=1?
# - 8. What is the average recency of purchases?
# - 9. Count customers by education level.
# - 10. What is the average number of web visits per month?
# - 11. What is the min/max income range?
# - 12. Find missing values in all columns.
# - 13. What is the distribution of teenhome variable?
# - 14. Count customers complaining (Complain=1).
# - 15. Which country has the highest number of customers?
# - 16. What percentage of customers accepted Cmp1?
# - 17. Show top 10 customers by wine spending.
# - 18. What is median web purchases?
# - 19. List top 5 most recent customers.
# - 20. Count customers grouped by marital status and education.

# %% [markdown]
# ## 🔵 Intermediate Level Questions

# %% [markdown]
# - 1. Explore correlation between income and wine spending.
# - 2. Identify which product category drives highest store purchases.
# - 3. Analyze effect of Recency on purchases (web/store/catalog).
# - 4. Cluster customers based on spending variables.
# - 5. Does higher income lead to more catalog purchases?
# - 6. Segment customers with high vs low web visits.
# - 7. Analyze income distribution by marital status.
# - 8. Compare spending patterns of customers with kids vs without kids.
# - 9. Determine which education group has highest response rate.
# - 10. Predict high spending customers (hypothesis-building).
# - 11. Find top indicators of campaign acceptance.
# - 12. Study relationship between NumDealsPurchases and Recency.
# - 13. Analyze multi-product buyers vs single-category buyers.
# - 14. Heatmap of all numerical correlations.
# - 15. Outlier analysis on income and spending.
# - 16. Identify top 5 customer personas using EDA.
# - 17. Compare online vs offline purchase behavior.
# - 18. Identify whether teenhome or kidhome contributes more to spending.
# - 19. Use groupby to find highest spending country/education segment.
# - 20. Analyze effect of customer age on spending.

# %% [markdown]
# ## 🔴 Hard / Advanced Questions

# %% [markdown]
# - 1. Build marketing funnel insights from acceptance variables.
# - 2. Segment customers for next marketing campaign using RFM.
# - 3. Predict churn using Recency and engagement metrics.
# - 4. Determine LTV (lifetime value) drivers using spending patterns.
# - 5. Build hypothesis: Does income influence multi-channel purchases?
# - 6. Derive product cross-selling insights using correlation and clustering.
# - 7. Performance analysis of campaigns across customer segments.
# - 8. Identify marketing strategy for high-value customers.
# - 9. Build personas using unsupervised learning-ready EDA.
# - 10. Detect anomalies in high spending categories.
# - 11. Multivariate analysis: Spending vs Recency vs Income.
# - 12. Compare digital-first customers vs store-first customers.
# - 13. Derive elasticities of response based on demographic variables.
# - 14. What variables influence Response most? (Feature importance mindset)
# - 15. Identify most profitable country and why.
# - 16. Build pre-ML model questions: Which features matter most?
# - 17. Calculate purchase probability groups using binning.
# - 18. Identify opportunity to reduce marketing cost using customer-level insights.
# - 19. Build scoring framework for marketing readiness.
# - 20. Create actionable recommendations based on complete EDA.

# %% [markdown]
# ## GROUP 3 — BUSINESS-CRITICAL QUESTIONS (HIGH VALUE, HIGH IMPACT)

# %% [markdown]
# ### A. Customer Segmentation & Behavior (Very High Impact)

# %% [markdown]
# 31.	    What factors define high-value customer segments?
# 32.	    Can customers be grouped using clustering (KMeans/Hierarchical)? What segments emerge?
# 33.	    How does total spending vary across different age groups?
# 34.	    Do customers with kids/teens spend significantly less?
# 35.	    Which demographic group contributes the highest revenue?
# 36.	    Which age group is most responsive to campaigns?
# 37.	    How do Recency patterns define active vs inactive customers?
# 38.	    Which products tend to be purchased together (market basket analysis)?
# 39.	    How can personas be created from this dataset?
# 40.	    How does customer behavior differ across countries?

# %% [markdown]
# ### B. Campaign & Marketing Strategy (Most Used in Real World)

# %% [markdown]
# 41.	    Which campaign (Cmp1–Cmp5) performed best, and why?
# 42.	    What customer attributes predict campaign acceptance?
# 43.	    How can acceptance be improved using data insights?
# 44.	    Are high-income customers more likely to accept campaigns?
# 45.	    Which channel (Web / Catalog / Store) performs best?
# 46.	    What drives the Response variable (final campaign acceptance)?
# 47.	    Do repeated campaign acceptances indicate loyalty?
# 48.	    Which group should be targeted for future campaigns?
# 49.	    How to allocate marketing budgets efficiently using this dataset?
# 50.	    Does education or marital status affect campaign success?

# %% [markdown]
# ### C. Churn, Loyalty & Retention (High Business Priority)

# %% [markdown]
# 51.	    Does Recency correlate with drop in purchases (churn risk)?
# 52.	    How many customers are at risk of churn (very high Recency)?
# 53.	    How does web visit frequency relate to churn probability?
# 54.	    Can churn prediction be built using Recency + last purchase patterns?
# 55.	    Which segments show early signs of disengagement?
# 56.	    What retention strategies should be applied to high-value customers?
# 57.	    How many loyal customers (low Recency + high Purchases) exist?
# 58.	    What features are the strongest indicators of customer loyalty?
# 59.	    Is the current marketing strategy causing customer fatigue?
# 60.	    How can customer LTV (Lifetime Value) be estimated?

# %% [markdown]
# ## GROUP 2 — EDA & INSIGHT QUESTIONS (MODERATE–HIGH CRITICALITY)

# %% [markdown]
# ### A. Spending Patterns & Product Behavior

# %% [markdown]
# 11.	    Which product category generates maximum revenue?
# 12.	    What is the correlation between spending on Wines, Meat, Gold, etc.?
# 13.	    Do high spenders on Wines also buy more from other categories?
# 14.	    Which products indicate luxury spending (e.g., GoldProds)?
# 15.	    Is there a seasonal pattern based on Dt_Customer?
# 16.	    How much does each customer spend overall (Total Mnt)?
# 17.	    Is income strongly correlated with total spending?
# 18.	    Which age group spends the highest on luxury items?
# 19.	    How does Recency affect total spending?
# 20.	    How do web vs catalog vs store purchases differ?

# %% [markdown]
# ### B. Demographic Analysis

# %% [markdown]
# 21.	    What is the age distribution of customers?
# 22.	    Which education group buys the most products?
# 23.	    Does marital status influence spending behavior?
# 24.	    Which demographic segments have the highest web visits?
# 25.	    Do customers from certain countries spend more?
# 26.	    How does household composition (Kidhome/Teenhome) affect buying?
# 27.	    Which demographics accept the highest campaigns?
# 28.	    Which group is most likely to complain?
# 29.	    Does income vary significantly across marital status?
# 30.	    Which age range has the highest response rate?

# %% [markdown]
# ## GROUP 1 — EASY / FUNDAMENTAL QUESTIONS (LOWER CRITICALITY, GOOD FOR BASICS)

# %% [markdown]
# ### A. Basic Summary & Exploration

# %% [markdown]
# 1. 	    What is the distribution of income?
# 2. 	    What is the average amount spent on Wines?
# 3. 	    How many customers accepted each campaign?
# 4. 	    How many customers complained?
# 5. 	    What is the average web visits per month?
# 6. 	    What is the average Recency?
# 7. 	    Which product has the lowest spending?
# 8. 	    What is the distribution of total purchases via Web?
# 9. 	    How many customers have kids vs teens?
# 10. 	 What are the top 10 customers with highest total spending?
