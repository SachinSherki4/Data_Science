# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Pandas have plot() which provide all matplotlib graphs functionality

# %%
batters= pd.read_csv('../../Data_Files/IPL_data/batter.csv')
batters
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
tips= sns.load_dataset('tips')
tips.plot(kind='hist', x='total_bill', title='Cost Analysis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, ylabel='Frequency'>

# %%
tips.plot(kind='scatter', x='total_bill',y='sex', title='Cost Analysis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='sex'>

# %%
stocks= pd.read_csv('../../Data_Files/NIFTY 200-07-02-2025-to-07-03-2025.csv')
stocks.head()
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  07-FEB-2025  13127.95  13167.05  13022.20  13092.85      1677888471
# 1  10-FEB-2025  13087.80  13100.75  12904.30  12943.05      1075615098
# 2  11-FEB-2025  12944.65  12949.65  12659.25  12712.75      1299440500
# 3  12-FEB-2025  12699.30  12755.55  12496.15  12697.25      1897060037
# 4  13-FEB-2025  12709.85  12829.80  12676.85  12700.80      1658152602
#
#    Turnover (₹ Cr)
# 0         56914.19
# 1         45352.03
# 2         54511.31
# 3         62195.38
# 4         52459.15
