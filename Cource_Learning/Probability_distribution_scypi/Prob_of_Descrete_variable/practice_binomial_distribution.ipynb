# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom, bernoulli, poisson

# %% [markdown]
# ### Binomial Distribution
#
# 1. Binomial distribution applicable for the problem when their is repeatation of same event to find probability of event (repeated trial of same thing)

# %% [markdown]
# Formula : (n/k) p^k (1-p)^ n=k
# where
# n= total no of trials
# k= finding prob
# p = given prob

# %% [markdown]
# Que1. A marketing campaign sends 100 emails with a 20% open rate. What’s the probability that exactly 25 people open it?

# %%
n= 100 # total no of email send
p= .20 # open rate
k= 25 # finding prob

pmf= binom.pmf(k,n,p)

pmf #0.0438
# Out:
# np.float64(0.04387783268941563)

# %% [markdown]
# Que2. In a factory, a machine produces 5% defective items. Out of 50 products, what’s the probability that exactly 3 are defective?

# %%
n= 50
k= 3
p= 0.05

pmf=binom.pmf(k,n,p)
pmf #0.2198
# Out:
# np.float64(0.21987483823058485)

# %% [markdown]
# Que3. A basketball player has a 70% chance of scoring a free throw. If she attempts 10 shots, what’s the probability she scores at least 8?

# %%
n= 10
k=8
p=0.7
pmf= binom.pmf(k,n,p)
pmf #0.2334
# Out:
# np.float64(0.2334744405000002)

# %% [markdown]
# Que 4. In a call center, each call has a 30% chance of being resolved in the first attempt. For 20 calls, find the probability exactly 5 are resolved.

# %%
n=20
k=5
p= .3 

pmf=binom.pmf(k,n,p)
pmf #0.178863
# Out:
# np.float64(0.17886305056987958)

# %% [markdown]
# Que5. In a startup hiring round, each candidate has a 40% chance of being selected. Out of 12 candidates, what’s the probability exactly 6 are selected?

# %%
p= 0.4
n=12
k= 6
pmf=binom.pmf(k,n,p)
pmf # 0.17657
# Out:
# np.float64(0.176579149824)

# %% [markdown]
# Que6. A website has a 10% conversion rate. If 200 people visit, what’s the probability exactly 25 convert?

# %%
p=0.1
n= 200
k=25

pmf= binom.pmf(k,n,p)
pmf #0.0444
# Out:
# np.float64(0.044436736976175444)

# %% [markdown]
# Que7. A cricket player has a 60% chance of hitting a boundary. In 15 balls, what’s the probability he hits 10 boundaries?

# %%
p = 0.6
n= 15
k=10

pmf= binom.pmf(k,n,p)
pmf # 0.18593
# Out:
# np.float64(0.18593784476467196)

# %% [markdown]
# Que8. A quality control engineer inspects 30 products. If the probability of defect is 2%, what’s the probability that none are defective?

# %%
p= 0.02
n= 30 
k = 0

pmf/ binom.pmf(k,n,p)
pmf #0.185937
# Out:
# np.float64(0.18593784476467196)

# %% [markdown]
# Que9. A coin is biased with 70% heads. Toss it 12 times. What’s the probability of getting exactly 9 heads?

# %%
p= 0.7
n= 12 
k=9
pmf=binom.pmf(k, n, p)
pmf #0.23970
# Out:
# np.float64(0.23970042558000001)

# %% [markdown]
# Que10. An insurance company finds 15% of customers claim in a year. For 40 customers, what’s the probability exactly 8 claim?

# %%
p = 0.15
n= 40
k = 8
pmf= binom.pmf(k,n,p)
pmf # 0.10866
# Out:
# np.float64(0.10866470190033728)
