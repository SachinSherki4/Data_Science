# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
tips= sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
gap=px.data.gapminder()
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.scatterplot(data=gap, x='lifeExp',y='gdpPercap', hue='continent',style='year')
# Out:
# <Axes: xlabel='lifeExp', ylabel='gdpPercap'>

# %%
sns.relplot(data=gap, x='lifeExp',y='gdpPercap', kind='scatter')

# %%
# when want to plot lifeExp vs gdpPercep for all years
sns.relplot(data=gap, x='lifeExp',y='gdpPercap', kind='scatter', col='year')

# %%
sns.relplot(data=gap, x='lifeExp',y='gdpPercap', kind='scatter', col='year', col_wrap=4)

# %%
# distribution plots

# %% [markdown]
# # distribution plots

# %% [markdown]
# > 1. Use for Univariate Analysis - analysis on single column
# > 2. Use to find out the distribution - ranges, mean, mode, central tendency, min, max, avg
# > 3. to check data has outlier or not?
# > 4. Data is binoial or not ?
#
# >> PLots under distribution plotting:
# >   1. Hist plot
# >   2. Kde plot
# >   3. Rug plot
#
# >> Functions:
# >   1. Figure level function: distplot()
# >   2. Axis level function:
# >       1. histplot()
# >       2. kdeplot()
# >       3. rugplot()

# %% [markdown]
# ### Hist Plot:
# > 1. Hist plot can be plot for both numerical or categorical variable

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# > Axis level distribution plotting

# %%
# numerical col
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# > Figure level Distribution plotting

# %%
# figure level distribution plotting
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
# categorical column
sns.histplot(data=gap, x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='Count'>

# %% [markdown]
# >   Bins generation

# %%
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
# bins genration - for large set of data - it is good
sns.displot(data=tips, x='total_bill', kind='hist', bins=25)

# %%
# bins genration - for large set of data - it is good
sns.displot(data=tips, x='total_bill', kind='hist', bins=5)

# %%
sns.displot(data=tips, x='day', kind='hist', bins=7)

# %% [markdown]
# > Histogram of tips basd on Sex

# %%
sns.displot(data=tips, x='tip',kind='hist', hue='sex', bins=10)

# %%
# element parameter - will remove columns and show rough plot
# bins genration - for large set of data - it is good
sns.displot(data=tips, x='tip',kind='hist', col='sex', bins=10, element='step')

# %%
# sns dataset
titanic =sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# hist plot for Age col
sns.displot(data=titanic, x='age', kind='hist', element='step', hue='sex')

# %%
sns.displot(data=titanic, x='age', kind='hist', element='step', col='survived')

# %% [markdown]
# ## KDE PLot : Kernel Density Estimation

# %% [markdown]
# >   Rather that using descrite bins, KDE plot smooth the observation with Gauscian kernel, producing continuous density estimation

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.kdeplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# kde plot represent the density of probability of total_bill 20 is 5% i.e 0.05
# from this we can see range of distribution from start to end like total_bill from 50-60 is nearly 0.3-4%

# %%
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# kdeplot using figure function
sns.displot(data=tips, x='total_bill', kind='kde')

# %%
# probability of density function of total_bill with compare to Sex Compare Male vs Female within each panel (Color-wise)
sns.displot(data=tips, x='total_bill', kind='kde', hue='sex', fill=True)

# %% [markdown]
# > How does the distribution of total bill amounts differ by gender, and how does that comparison change for smokers vs non-smokers?”

# %%
# probability of density function of total_bill with compare to Sex 
sns.displot(data=tips, x='total_bill', kind='kde', hue='sex', fill=True,col='smoker')

# %% [markdown]
# # Rug Plot
#
# > Plot marginal distribution by drawing ticks along with the x and y axis
# > This function intended to complement other plots by showing location of individual observation in an unobstructive way

# %%
sns.kdeplot(data=tips, x='total_bill')
sns.rugplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Bivariate kde plotting - smoothen the x, y observation with a 2D
sns.kdeplot(data=tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
