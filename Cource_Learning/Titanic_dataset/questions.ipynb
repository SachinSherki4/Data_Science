# %% [markdown]
# ### Ques 1. Group the Titanic dataset columns into Numeric, Categorical, Text, Date, Boolean based on their TRUE meaning, not their dtype.

# %% [markdown]
# ### 2. Give me the exact dtype assigned by Pandas AND the correct dtype it should have based on domain meaning
