# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('../../Data_Files/Titanic.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 39            40         1       3
# 528          529         0       3
# 858          859         1       3
# 225          226         0       3
# 167          168         0       3
# 430          431         1       1
# 42            43         0       3
# 56            57         1       2
# 49            50         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 15                  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 39                       Nicola-Yarred, Miss. Jamila  female  14.0      1
# 528                        Salonen, Mr. Johan Werner    male  39.0      0
# 858            Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 225                     Berglund, Mr. Karl Ivar Sven    male  22.0      0
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# ...

# %%
# capture the ticket Coach
df['Ticket_coach']=  df['Ticket'].str.split().str[0].fillna('Gen').astype('category')

# %%
df['Ticket_coach'].value_counts()
# Out:
# Ticket_coach
# PC        60
# C.A.      27
# STON/O    12
# A/5       10
# W./C.      9
#           ..
# 112050     1
# 111428     1
# 111427     1
# 111426     1
# 111369     1
# Name: count, Length: 557, dtype: int64

# %%
df.select_dtypes(include=['number']).memory_usage(deep=True)
# Out:
# Index           132
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Age            7128
# SibSp          7128
# Parch          7128
# Fare           7128
# dtype: int64

# %%
df.loc[(df['Pclass']==1) & (df['Sex']=='female'), "Name"].value_counts()
# Out:
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Bonnell, Miss. Elizabeth                               1
# Spencer, Mrs. William Augustus (Marie Eugenie)         1
# Harper, Mrs. Henry Sleeper (Myna Haxtun)               1
#                                                       ..
# Wick, Mrs. George Dennick (Mary Hitchcock)             1
# Swift, Mrs. Frederick Joel (Margaret Welles Barron)    1
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          1
# Graham, Miss. Margaret Edith                           1
# Name: count, Length: 94, dtype: int64

# %%
df['Ticket'].map(lambda x : type(x)).value_counts()
# Out:
# Ticket
# <class 'str'>    891
# Name: count, dtype: int64

# %%
df['Age'].sample(10)
# Out:
# 295     NaN
# 572    36.0
# 559    36.0
# 537    30.0
# 593     NaN
# 445     4.0
# 603    44.0
# 316    24.0
# 94     59.0
# 107     NaN
# Name: Age, dtype: float64
