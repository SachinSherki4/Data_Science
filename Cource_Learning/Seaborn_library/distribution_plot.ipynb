# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# > 1. User for Univariate Analysis - analysing particular column independely
# > 2. Used to find out the distribution
# > 3. Range of observation
# > 4. Central Tendencies
# > 5. Outlier

# %% [markdown]
# `Plot under Distribution Plot`
# > 1. Histplot
# > 2. Kde plot
# > 3. rugplot
